# %%
import os
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from mailfox.email_interface import EmailHandler
from mailfox.email_interface import EmailLLM
from mailfox.vector import VectorDatabase
from mailfox.vector import FolderCluster

# %%
# Read credentials from txt file
with open('credentials.txt') as f:
    lines = f.readlines()
    username = lines[0].strip()
    password = lines[1].strip()

email_handler = EmailHandler(username, password)

# %%
# Notifications, Newsletters, Finance, Jobs
flagged_folders = ['Notifications', 'Newsletters', 'Finance', 'Jobs']
folders = email_handler.get_all_folders()
flagged_folders_and_subfolders = [folder for folder in folders if any(flagged_folder in folder for flagged_folder in flagged_folders)]

# %%
email_handler.get_subfolders(flagged_folders)
# Out:
# ['"Finance"',
#  '"Finance/Bills"',
#  '"Finance/Credit Cards"',
#  '"Finance/Purchases"',
#  '"Finance/Statements"',
#  '"Jobs"',
#  '"Newsletters"',
#  '"Notifications"',
#  '"Notifications/Messages"',
#  '"Notifications/Research"',
#  '"Notifications/Safety"',
#  '"Notifications/Security"',
#  '"Notifications/Shopping"',
#  '"Notifications/Shopping/Sales"',
#  '"Notifications/Shopping/Shipping"',
#  '"Notifications/Social"',
#  '"Notifications/Support"',
#  '"Notifications/Surveys"']

# %%
save_path = "email_db"
db_path = os.path.join(save_path, "chroma_db")
clustering_path = os.path.join(save_path, "clustering.pkl")
vector_db = VectorDatabase(db_path)

# %%
if not os.path.exists('all_mail.pkl'):
    print("Fetchin all Mail")
    # all_mail = email_handler.get_mail(filter='unseen', return_dataframe=True)
    # uids = email_handler.get_all_mail_uids()
    # all_mail = email_handler.get_mail(filter='uids', uids=uids[-5000:], return_dataframe=True)
    
    all_mail = email_handler.get_mail(filter='all', folders=flagged_folders_and_subfolders, return_dataframe=True)
    all_mail.to_pickle('all_mail.pkl')
else:
    all_mail = pd.read_pickle('all_mail.pkl')

# %%
all_mail.head()
# Out:
#   uid                  folder  \
# 0   1               "Finance"
# 1   1         "Finance/Bills"
# 2   2         "Finance/Bills"
# 3   1  "Finance/Credit Cards"
# 4   2  "Finance/Credit Cards"
#
#                                                 uuid  \
# 0  bef768d82e7b75cc4cd315883a36273943a7bb285fcda9...
# 1  7f871015d78593a12d327b9cdf3f688ff0751129a67bfe...
# 2  9f6d8f3e185bbdc6811177ed84e2f818aaa93ec098598b...
# 3  291bdd42f4acf7242bd453619e16ef7a7aa020ffa920a2...
# 4  cbeeeb6c259fd1bad68815cd7ea2fb72a6c3f08f833b8b...
#
#                                                 from  \
# 0             Quicken Simplifi <noreply@quicken.com>
# 1            Conservice <service@conservicemail.com>
# 2  Britni Purcell CIS Abroad <bpurcell@cisabroad....
# 3                  Chase <no.reply.alerts@chase.com>
# 4                  Chase <no.reply.alerts@chase.com>
#
#                                                   to  \
# 0                             alex.k.korte@gmail.com
# 1    alex.k.korte@gmail.com, jeffrey.korte@gmail.com
# 2  "alex.k.korte@gmail.com" <alex.k.korte@gmail.com>
# 3                             alex.k.korte@gmail.com
# 4                             alex.k.korte@gmail.com
#
#                                              subject  \
# 0                                b'\xf0\x9f\x94\x94'
# 1  Utility Billing Frequently Asked Questions dur...
# 2         6 DAYS: Final Payment Deadline for May 5th
# 3               You're now sharing data with Quicken
# 4              Your credit card payment is scheduled
#
#                         date  \
# 0  Wed, 15 May 2024 13:51:50
# 1  Wed, 15 May 2024 12:17:13
# 2  Tue, 30 Apr 2024 08:17:19
# 3  Sun, 19 May 2024 22:15:48
# 4  Sun, 19 May 2024 22:12:11
#
#                                                 body  \
# 0  Categorize your transactions to keep your bill...
# 1  \n\n\n\n\n\n\n\n \n \n\n\n \nDear Valued Resid...
# 2  Hello Alex,\r\n\r\nThis is a friendly reminder...
# 3  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 4  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPayment sche...
#
#                                             raw_body
# 0  Categorize your transactions to keep your bill...
# 1  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 2  Hello Alex,\r\n\r\nThis is a friendly reminder...
# 3  \r\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1...
# 4  <html xmlns="http://www.w3.org/1999/xhtml" lan...

# %%
for idx, mail in tqdm(all_mail.iterrows(), desc="Generating Database", total=all_mail.shape[0]):
    embedding = vector_db.embed_email(mail)
    
    vector_db.emails_collection.add(
        ids=[mail['uuid']],
        embeddings=embedding,
        metadatas=dict(mail.drop('uuid'))
    )
# Out:
# Generating Database:   0%|          | 0/221 [00:00<?, ?it/s]

# %%
folder_vectors = {}
for folder in flagged_folders_and_subfolders:
    folder_vectors[folder] = np.array(vector_db.emails_collection.get(where={'folder': folder}, include=['embeddings'])['embeddings'])

# %%
folder_vectors["\"Finance/Bills\""]
# Out:
# array([[ 6.59638457e-03,  2.97274813e-03,  5.54245897e-04,
#         -2.67004296e-02,  1.44617679e-02, -6.16418011e-02,
#          1.52548319e-02, -8.20252486e-03,  3.30192223e-02,
#          2.54192147e-02, -2.49492761e-04,  4.57124971e-03,
#          1.48062790e-02, -1.53143099e-02, -1.31618213e-02,
#          9.03726742e-03,  2.80711725e-02, -3.51677872e-02,
#         -2.74632759e-02,  2.18292288e-02,  2.16355901e-02,
#          2.49656122e-02, -7.97913149e-02,  2.51616240e-02,
#          4.40478660e-02,  4.32761908e-02, -1.16827041e-02,
#         -1.36506753e-02, -6.50859624e-02, -1.67003665e-02,
#          1.67975889e-03, -1.08252345e-02,  7.23657012e-03,
#         -7.11737946e-02,  5.17301038e-02,  5.38936183e-02,
#          1.92155894e-02,  1.02559878e-02,  6.19021058e-02,
#          4.98512900e-03, -1.16240131e-02, -7.72179058e-03,
#          3.35731730e-02, -1.18435966e-02, -1.99830569e-02,
#          3.44166346e-02, -2.62247343e-02, -6.60912972e-03,
#         -5.56213362e-03,  5.13496771e-02,  4.62687295e-03,
#         -3.21933851e-02, -2.49641445e-02,  4.87064533e-02,
#         -2.27814186e-02,  3.94023731e-02,  5.74760213e-02,
#         -1.08269034e-02,  8.78683757e-03, -1.36492047e-02,
#          6.54366799e-04,  1.09466854e-02, -3.49224173e-02,
#          7.53721595e-02, -3.36737148e-02, -1.29754674e-02,
#          8.61466106e-04,  1.30829290e-02, -1.89545956e-02,
lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/stelath/micromamba/envs/ml/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# (18, 18)

# %%
for i in list(centroids.values()):
    print(type(i))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>

# %%
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
nbrs = KNeighborsClassifier(n_neighbors=3, weights='distance').fit(np.array(centroids.values()), range(len(folder_vectors.keys())))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
# ----> 2 nbrs = KNeighborsClassifier(n_neighbors=3, weights='distance').fit(np.array(centroids.values()), range(len(folder_vectors.keys())))
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:238, in KNeighborsClassifier.fit(self, X, y)
#     216 @_fit_context(
#     217     # KNeighborsClassifier.metric is not validated yet
#     218     prefer_skip_nested_validation=False
#     219 )
#     220 def fit(self, X, y):
#     221     """Fit the k-nearest neighbors classifier from the training dataset.
#     222
#     223     Parameters
#    (...)
#     236         The fitted k-nearest neighbors classifier.
#     237     """
# --> 238     return self._fit(X, y)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/neighbors/_base.py:476, in NeighborsBase._fit(self, X, y)
#     474 if self._get_tags()["requires_y"]:
#     475     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 476         X, y = self._validate_data(
#     477             X, y, accept_sparse="csr", multi_output=True, order="C"
#     478         )
#     480     if is_classifier(self):
#     481         # Classification targets require a specific format
#     482         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/validation.py:997, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995         array = xp.astype(array, dtype, copy=False)
#     996     else:
# --> 997         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998 except ComplexWarning as complex_warning:
#     999     raise ValueError(
#    1000         "Complex data not supported\n{}\n".format(array)
#    1001     ) from complex_warning
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# TypeError: float() argument must be a string or a real number, not 'dict_values'

# %%
clustering = FolderCluster(folder_vectors)
clustering.save_model(clustering_path)
# Out:
# /Users/stelath/micromamba/envs/ml/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/stelath/micromamba/envs/ml/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 clustering = FolderCluster(folder_vectors)
#       2 clustering.save_model(clustering_path)
#
# File ~/Documents/GitHub/MailFox/mailfox/vector/clustering.py:44, in FolderCluster.__init__(self, folders)
#      42 self.folders = list(folders.keys())
#      43 self.centroids = {folder: np.mean(vectors, axis=0) for folder, vectors in folders.items()}
# ---> 44 self.nbrs = KNeighborsClassifier(n_neighbors=3, weights='distance').fit(list(self.centroids.values()), range(len(self.folders)))
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:238, in KNeighborsClassifier.fit(self, X, y)
#     216 @_fit_context(
#     217     # KNeighborsClassifier.metric is not validated yet
#     218     prefer_skip_nested_validation=False
#     219 )
#     220 def fit(self, X, y):
#     221     """Fit the k-nearest neighbors classifier from the training dataset.
#     222
#     223     Parameters
#    (...)
#     236         The fitted k-nearest neighbors classifier.
#     237     """
# --> 238     return self._fit(X, y)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/neighbors/_base.py:476, in NeighborsBase._fit(self, X, y)
#     474 if self._get_tags()["requires_y"]:
#     475     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 476         X, y = self._validate_data(
#     477             X, y, accept_sparse="csr", multi_output=True, order="C"
#     478         )
#     480     if is_classifier(self):
#     481         # Classification targets require a specific format
#     482         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/validation.py:997, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995         array = xp.astype(array, dtype, copy=False)
#     996     else:
# --> 997         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998 except ComplexWarning as complex_warning:
#     999     raise ValueError(
#    1000         "Complex data not supported\n{}\n".format(array)
#    1001     ) from complex_warning
#
# File ~/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (18,) + inhomogeneous part.

# %%
if not os.path.exists('new_mail.pkl'):
    new_mail = email_handler.get_mail(filter='unseen', return_dataframe=True)
    new_mail.to_pickle('new_mail.pkl')
else:
    new_mail = pd.read_pickle('new_mail.pkl')

# %%
import random

# Get a random email from new_mail
random_email = new_mail.sample(n=1)
random_email = random_email.to_dict(orient='records')[0]

embedding = vector_db.embed_email(random_email)
predicted_folder = clustering.predict(embedding)

# Print the email details and predicted folder
print(f"Predicted Folder: {predicted_folder}")
print(f"Email Details:")
for key, value in random_email.items():
    print(f"{key}: {value}")
# Out:
# Predicted Folder: ['"Newsletters"']
# Email Details:
# uid: 34288
# folder: INBOX
# uuid: ac9cb39b576da020ac2af9d67f204e0330f2cd92195065685e66be58acd577bf
# from: Medium Daily Digest <noreply@medium.com>
# to: alex.k.korte@gmail.com
# subject: Quantum Mechanics Meets PCA: An (Un)expected Convergence | Rodrigo
#  Silva in Towards Data Science
# date: Sat, 25 May 2024 05:20:00
# body: Stories for Alex K
# @alex.k.korte (https://medium.com/@alex.k.korte?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Member (https://medium.com/@alex.k.korte?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#
# Today's highlights
#
# Rodrigo Silva (https://medium.com/@rodrigopesilva?source=email-6e8d4e436d47-1716624990035-digest.reader-7f60cf5620c9-5e04bcb16376----0-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Towards Data Science (https://medium.com/towards-data-science?source=email-6e8d4e436d47-1716624990035-digest.reader-7f60cf5620c9-5e04bcb16376----0-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·8 min read
#
# Quantum Mechanics Meets PCA: An (Un)expected Convergence
#
# How quantum states and PCA components connect
#
# Raphael Moutard (https://medium.com/@raphael.moutard?source=email-6e8d4e436d47-1716624990035-digest.reader--09ad0f787888----1-94------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·5 min read
#
# The Controversial Truth about Tech Debt
#
# Of all the buzzwords invented by the software industry, Technical Debt is the most frustrating. I know thisâ¦
#
# Zhimin Zhan (https://medium.com/@zhiminzhan?source=email-6e8d4e436d47-1716624990035-digest.reader--a149852fcbf3----2-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·11 min read
#
# What Happened to ThoughtWorks?
#
# Why has a leading software technical consultancy firm, once renowned for its innovation and positive impactâ¦
#
# Webjinnee (https://medium.com/@webjinneeofficial?source=email-6e8d4e436d47-1716624990035-digest.reader-63e328c0fcb7-cef74cc26419----3-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in ðð ð¦ð¨ð§ð¤ð¬.ð¢ð¨ (https://medium.com/aimonks?source=email-6e8d4e436d47-1716624990035-digest.reader-63e328c0fcb7-cef74cc26419----3-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·4 min read
#
# 50 Tasks that ChatGPT Can Do in Seconds with These Simple Prompts (Part-2)
#
# You've probably heard of ChatGPT by nowâ-âthat incredibly smart AI can understand and communicate just like aâ¦
#
# Alexander obidiegwu (https://medium.com/@alexobidiegwu?source=email-6e8d4e436d47-1716624990035-digest.reader--6942c7cafd56----4-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·23 min read
#
# 50 Coding Laws That Would Make You A Decent Programmer.
#
# Follow these laws or get fired.
#
# Koushik (https://medium.com/@koushikkushal95?source=email-6e8d4e436d47-1716624990035-digest.reader--d18e299bb438----5-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·12 min read
#
# Understanding Convolutional Neural Networks (CNNs) in Depth
#
# Convolutional Neural Networks skillfully capturing and extracting patterns from data, revealing the hiddenâ¦
#
# Selcuk Ozdemir (https://medium.com/@scozdev?source=email-6e8d4e436d47-1716624990035-digest.reader-4b3a1ed4f11c-4852109ffee5----6-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in JavaScript in Plain English (https://medium.com/javascript-in-plain-english?source=email-6e8d4e436d47-1716624990035-digest.reader-4b3a1ed4f11c-4852109ffee5----6-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·3 min read
#
# Write a React Component Like a Pro
#
# In the world of React, writing components is an art. It's not just about making them workâ-âit's about makingâ¦
#
# Pablo Porto (https://medium.com/@pablo.porto?source=email-6e8d4e436d47-1716624990035-digest.reader-5517fd7b58a6-873d5d4ae4a2----7-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Level Up Coding (https://medium.com/gitconnected?source=email-6e8d4e436d47-1716624990035-digest.reader-5517fd7b58a6-873d5d4ae4a2----7-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·11 min read
#
# 10 unconventional lessons from 10 years working as a software engineer
#
# Practical advice to build an effective and sustainable career in tech
#
# Å imon TÃ³th (https://medium.com/@simontoth?source=email-6e8d4e436d47-1716624990035-digest.reader-5b301f10ddcd-7ef0b5bc64a1----8-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in ITNEXT (https://medium.com/itnext?source=email-6e8d4e436d47-1716624990035-digest.reader-5b301f10ddcd-7ef0b5bc64a1----8-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·16 min read
#
# Daily bit(e) of C++ | Optimizing code to run 87x faster
#
# Daily bit(e) of C++ #474, Optimizing C++ code to run 87x faster for the One Billion Row Challenge (1brc).
#
# Nathan Rosidi (https://medium.com/@nathanrosidi?source=email-6e8d4e436d47-1716624990035-digest.reader--aae78826712f----9-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·19 min read
#
# Top 10 Machine Learning Algorithms for Beginner Data Scientists
#
# Let's explore the machine learning algorithms perfect for beginners in data science. We'll explain each oneâ¦
#
# Niels Cautaerts (https://medium.com/@cautaerts?source=email-6e8d4e436d47-1716624990035-digest.reader-d0b105d10f0a-af81eb8d3949----10-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Better Programming (https://medium.com/better-programming?source=email-6e8d4e436d47-1716624990035-digest.reader-d0b105d10f0a-af81eb8d3949----10-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·14 min read
#
# Data Engineering is Not Software Engineering
#
# Pretending like data and software are the same is counterproductive to the success of your data engineers
#
# Dylan Combellick (https://medium.com/@dylan_combellick?source=email-6e8d4e436d47-1716624990035-digest.reader--2e52cc2990c5----11-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·10 min read
#
# Why America is So Hard
#
# An Emigrant from the US, Living in Europe
#
# Akshay S B (https://medium.com/@akshaysbabu?source=email-6e8d4e436d47-1716624990035-digest.reader-d1f54550947b-cac121b5ab38----12-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Mac O'Clock (https://medium.com/macoclock?source=email-6e8d4e436d47-1716624990035-digest.reader-d1f54550947b-cac121b5ab38----12-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·14 min read
#
# Free 10 Mac Apps that you didn't know you Needed
#
# Photo by Sora Sagano on Unsplash
#
# Volker Janz (https://medium.com/@vojay?source=email-6e8d4e436d47-1716624990035-digest.reader-f2ba5b8f6eb3-0ff19edb9d76----13-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Data Engineer Things (https://medium.com/data-engineer-things?source=email-6e8d4e436d47-1716624990035-digest.reader-f2ba5b8f6eb3-0ff19edb9d76----13-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·28 min read
#
# Minds and Machinesâ-âAI for Mental Health Support, Fine-Tuning LLMs with LoRAâ¦
#
# Explore the potential of Large Language Models (LLMs) changing the future of mental healthcare and learn howâ¦
#
# Melissa Richard (https://medium.com/@devhellomello?source=email-6e8d4e436d47-1716624990035-digest.reader--60cf3879bad8----14-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·18 min read
#
# New Computer Setup for Techies 2024: NeoVim and Ollama and fish, oh my!
#
# Greetings Cloudlings!!
#
# See more of what you like and less of what you don't.
# Control your recommendations (https://medium.com/me/missioncontrol?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#
# Read from anywhere.
#
# Sent by Medium (https://medium.com/?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Medium, 548 Market St, PMB 42061, SanÂ Francisco,Â CAÂ 94104
# Unsubscribe (https://medium.com/me/email-settings/6e8d4e436d47/da3888d72dd3?type=social&source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#  from this type of emailÂ·Switch to the Weekly Digest (https://medium.com/me/email-settings/6e8d4e436d47/da3888d72dd3?type=social&preference=2&source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Careers (https://medium.com/jobs-at-medium/work-at-medium-959d1a85284e?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Help Center (https://help.medium.com/hc/en-us?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Privacy Policy (https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Terms of service (https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# raw_body: Stories for Alex K
# @alex.k.korte (https://medium.com/@alex.k.korte?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Member (https://medium.com/@alex.k.korte?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#
# Today's highlights
#
# Rodrigo Silva (https://medium.com/@rodrigopesilva?source=email-6e8d4e436d47-1716624990035-digest.reader-7f60cf5620c9-5e04bcb16376----0-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Towards Data Science (https://medium.com/towards-data-science?source=email-6e8d4e436d47-1716624990035-digest.reader-7f60cf5620c9-5e04bcb16376----0-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·8 min read
#
# Quantum Mechanics Meets PCA: An (Un)expected Convergence
#
# How quantum states and PCA components connect
#
# Raphael Moutard (https://medium.com/@raphael.moutard?source=email-6e8d4e436d47-1716624990035-digest.reader--09ad0f787888----1-94------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·5 min read
#
# The Controversial Truth about Tech Debt
#
# Of all the buzzwords invented by the software industry, Technical Debt is the most frustrating. I know thisâ¦
#
# Zhimin Zhan (https://medium.com/@zhiminzhan?source=email-6e8d4e436d47-1716624990035-digest.reader--a149852fcbf3----2-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·11 min read
#
# What Happened to ThoughtWorks?
#
# Why has a leading software technical consultancy firm, once renowned for its innovation and positive impactâ¦
#
# Webjinnee (https://medium.com/@webjinneeofficial?source=email-6e8d4e436d47-1716624990035-digest.reader-63e328c0fcb7-cef74cc26419----3-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in ðð ð¦ð¨ð§ð¤ð¬.ð¢ð¨ (https://medium.com/aimonks?source=email-6e8d4e436d47-1716624990035-digest.reader-63e328c0fcb7-cef74cc26419----3-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·4 min read
#
# 50 Tasks that ChatGPT Can Do in Seconds with These Simple Prompts (Part-2)
#
# You've probably heard of ChatGPT by nowâ-âthat incredibly smart AI can understand and communicate just like aâ¦
#
# Alexander obidiegwu (https://medium.com/@alexobidiegwu?source=email-6e8d4e436d47-1716624990035-digest.reader--6942c7cafd56----4-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·23 min read
#
# 50 Coding Laws That Would Make You A Decent Programmer.
#
# Follow these laws or get fired.
#
# Koushik (https://medium.com/@koushikkushal95?source=email-6e8d4e436d47-1716624990035-digest.reader--d18e299bb438----5-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·12 min read
#
# Understanding Convolutional Neural Networks (CNNs) in Depth
#
# Convolutional Neural Networks skillfully capturing and extracting patterns from data, revealing the hiddenâ¦
#
# Selcuk Ozdemir (https://medium.com/@scozdev?source=email-6e8d4e436d47-1716624990035-digest.reader-4b3a1ed4f11c-4852109ffee5----6-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in JavaScript in Plain English (https://medium.com/javascript-in-plain-english?source=email-6e8d4e436d47-1716624990035-digest.reader-4b3a1ed4f11c-4852109ffee5----6-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·3 min read
#
# Write a React Component Like a Pro
#
# In the world of React, writing components is an art. It's not just about making them workâ-âit's about makingâ¦
#
# Pablo Porto (https://medium.com/@pablo.porto?source=email-6e8d4e436d47-1716624990035-digest.reader-5517fd7b58a6-873d5d4ae4a2----7-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Level Up Coding (https://medium.com/gitconnected?source=email-6e8d4e436d47-1716624990035-digest.reader-5517fd7b58a6-873d5d4ae4a2----7-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·11 min read
#
# 10 unconventional lessons from 10 years working as a software engineer
#
# Practical advice to build an effective and sustainable career in tech
#
# Å imon TÃ³th (https://medium.com/@simontoth?source=email-6e8d4e436d47-1716624990035-digest.reader-5b301f10ddcd-7ef0b5bc64a1----8-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in ITNEXT (https://medium.com/itnext?source=email-6e8d4e436d47-1716624990035-digest.reader-5b301f10ddcd-7ef0b5bc64a1----8-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·16 min read
#
# Daily bit(e) of C++ | Optimizing code to run 87x faster
#
# Daily bit(e) of C++ #474, Optimizing C++ code to run 87x faster for the One Billion Row Challenge (1brc).
#
# Nathan Rosidi (https://medium.com/@nathanrosidi?source=email-6e8d4e436d47-1716624990035-digest.reader--aae78826712f----9-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·19 min read
#
# Top 10 Machine Learning Algorithms for Beginner Data Scientists
#
# Let's explore the machine learning algorithms perfect for beginners in data science. We'll explain each oneâ¦
#
# Niels Cautaerts (https://medium.com/@cautaerts?source=email-6e8d4e436d47-1716624990035-digest.reader-d0b105d10f0a-af81eb8d3949----10-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Better Programming (https://medium.com/better-programming?source=email-6e8d4e436d47-1716624990035-digest.reader-d0b105d10f0a-af81eb8d3949----10-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·14 min read
#
# Data Engineering is Not Software Engineering
#
# Pretending like data and software are the same is counterproductive to the success of your data engineers
#
# Dylan Combellick (https://medium.com/@dylan_combellick?source=email-6e8d4e436d47-1716624990035-digest.reader--2e52cc2990c5----11-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·10 min read
#
# Why America is So Hard
#
# An Emigrant from the US, Living in Europe
#
# Akshay S B (https://medium.com/@akshaysbabu?source=email-6e8d4e436d47-1716624990035-digest.reader-d1f54550947b-cac121b5ab38----12-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Mac O'Clock (https://medium.com/macoclock?source=email-6e8d4e436d47-1716624990035-digest.reader-d1f54550947b-cac121b5ab38----12-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·14 min read
#
# Free 10 Mac Apps that you didn't know you Needed
#
# Photo by Sora Sagano on Unsplash
#
# Volker Janz (https://medium.com/@vojay?source=email-6e8d4e436d47-1716624990035-digest.reader-f2ba5b8f6eb3-0ff19edb9d76----13-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
#  in Data Engineer Things (https://medium.com/data-engineer-things?source=email-6e8d4e436d47-1716624990035-digest.reader-f2ba5b8f6eb3-0ff19edb9d76----13-102------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·28 min read
#
# Minds and Machinesâ-âAI for Mental Health Support, Fine-Tuning LLMs with LoRAâ¦
#
# Explore the potential of Large Language Models (LLMs) changing the future of mental healthcare and learn howâ¦
#
# Melissa Richard (https://medium.com/@devhellomello?source=email-6e8d4e436d47-1716624990035-digest.reader--60cf3879bad8----14-98------------------d476d917_ea85_4e87_a0d8_f8a323938ac7-1)
# Â·18 min read
#
# New Computer Setup for Techies 2024: NeoVim and Ollama and fish, oh my!
#
# Greetings Cloudlings!!
#
# See more of what you like and less of what you don't.
# Control your recommendations (https://medium.com/me/missioncontrol?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#
# Read from anywhere.
#
# Sent by Medium (https://medium.com/?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Medium, 548 Market St, PMB 42061, SanÂ Francisco,Â CAÂ 94104
# Unsubscribe (https://medium.com/me/email-settings/6e8d4e436d47/da3888d72dd3?type=social&source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
#  from this type of emailÂ·Switch to the Weekly Digest (https://medium.com/me/email-settings/6e8d4e436d47/da3888d72dd3?type=social&preference=2&source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Careers (https://medium.com/jobs-at-medium/work-at-medium-959d1a85284e?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Help Center (https://help.medium.com/hc/en-us?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Privacy Policy (https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# Â·Terms of service (https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=email-6e8d4e436d47-1716624990035-digest.reader-------------------------d476d917_ea85_4e87_a0d8_f8a323938ac7)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
emailLLM = EmailLLM('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')

# %%
(0.5/1000000) * (750/1000) * len(random_email['body']) * 300
# Out:
# 0.8952749999999999

# %%
random_email = new_mail.sample(n=1)
random_email = random_email.to_dict(orient='records')[0]

predicted_folder = emailLLM.predict_folder(random_email, flagged_folders_and_subfolders)

# Print the email details and predicted folder
print(f"Predicted Folder: {predicted_folder}")
print(f"Email Details:")
for key, value in random_email.items():
    if key == 'raw_body':
        continue
    print(f"{key}: {value}")
# Out:
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8496220b90f1d96cfc385e3c1fb637219f34346ce9eb3a88b7f22946d9428bc348348a5cf2a78de569a1526c8de93ff0f4e4c585f16a7827f
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8496220b90f1d96cfc385e3c1fb637219f34346ce9eb3a88b7f22946d9428bc348348a5cf2a78de569a1526c8de93ff0f4e4c585f16a7827f
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8e721d019cb8008fe74b264fc232f0e4715edea6b723cfa6b1e09441ca1fab4d497aef84b6666853338fa8bef39f7c343315bca1c6fe7eda7
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8ed62244a215d61014a87c0e755c9fcef0649641deada3645da3986b7b79d266c7929fd6e126af7eb5cc23fdf10a5cfc7e00d4485f3593fed
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8329484b65121874d3c67f7733c97cf957d1716e1377db94d971317cf897c63f64fd459f17ef50324269cc81cad1f9952e856369a88ea1f0e
#
#
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f8c5bf462e9d03334f6021ef24e02deaa752963c363f0f83f2ca89ba3a192baf33b6f5aaa965e876b0d759c89ab04bf6de43cdb39b0826a2cd
# With every order shipped, we\u2019re offsetting our carbon emissions. See How
#
#
#
#
# https://click.e.thenorthface.com/?qs=5f793a48910814f862807ef343dedbfcbf631c24512ec3c6b93341f07226beac355d2201db09d73b683427b8424afa17d236e9ec8b3b8e6752320b77bb5efdaf
# Find A Store
# https://click.e.thenorthface.com/?qs=5f793a48910814f8d47efa256db08dc095d8265a722950cf9dc961d161ea06fb9a2d2714117316a72638fda024e7aa3a421071f605aa8103581f08d4b16a2766
# Unsubscribe
# https://view.e.thenorthface.com/?qs=15cdb31c63d25733c8d7b43a5b17518a2b72e56a8851c431d1324155dc72febf4e3f89e563d36b97f0872590a5a8484bff008a5512ad06061b856f56e028ef81199f4b8f36f2c2c2335acfb882afe281
# View In Browser
#
#
#
# The North Face | 1551 Wewatta St.
#
#  Denver, CO 80202
#
#  (888) TNF-1968

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(random_email['body'], 'lxml')
soup.get_text()
# Out:
# "EcoFlow's Survey\n\n\nWe'd love to hear what you think of our customer service.\nPlease take a moment to answer some simple questions by clicking\nthe link below:\n\n\n\nSTART SURVEY\n\n\n\r\nÂ\xa0\r\n\r\nOr copy paste the URL below into your internet browser.\nhttps://nam.dcv.ms/eRHduBKLuQ\n\n\nThis is a system generated email, please do not reply to it. The survey link in this email is unique to its recipient. Please do not forward this email. If you would like to unsubscribe and stop receiving these emails, click unsubscribe.\n\n\n"

# %%
random_email['body']
# Out:
# "\n\n\nEcoFlow's Survey\n\n\nWe'd love to hear what you think of our customer service.\nPlease take a moment to answer some simple questions by clicking\nthe link below:\n\n\n\nSTART SURVEY\n\n\n\r\nÂ\xa0\r\n\r\nOr copy paste the URL below into your internet browser.\nhttps://nam.dcv.ms/eRHduBKLuQ\n\n\nThis is a system generated email, please do not reply to it. The survey link in this email is unique to its recipient. Please do not forward this email. If you would like to unsubscribe and stop receiving these emails, click unsubscribe.\n\n\n"

# %%
email_handler.move_mail([random_email['uid']], '"Finance/Bills"')
# Out:
# ('OK', [None])
# Moved 34136 to "Finance/Bills"
